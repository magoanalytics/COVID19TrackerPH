# %%
import pandas as pd
import nltk
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
import glob
from dateutil import parser
import re
from geotext import GeoText
import numpy as np
from scipy import stats 
import geopandas as gpd
import datetime

# Spacy for tokenizing our texts

import spacy
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English

# Gensim is needed for modeling

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.utils import tokenize
from gensim.parsing.preprocessing import preprocess_string, strip_punctuation, strip_numeric
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Gab Daos\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Setting up Spacy Tokenizer
nlp = English()

def lemmatizer(doc):
    # This takes in a doc of tokens from the NER and lemmatizes them. 
    # Pronouns (like "I" and "you" get lemmatized to '-PRON-', so I'm removing those.
    doc = [token.lemma_ for token in doc if token.lemma_ != '-PRON-']
    doc = u' '.join(doc)
    return nlp.make_doc(doc)
    
def remove_stopwords(doc):
    # This will remove stopwords and punctuation.
    # Use token.text to return strings, which we'll need for Gensim.
    doc = [token.text for token in doc if token.is_stop != True and token.is_punct != True]
    return doc

# This will add pipelines in our tokenization process.

nlp.add_pipe(lemmatizer,name='lemmatizer')
nlp.add_pipe(remove_stopwords, name="stopwords", last=True)

# %%
# This is a function that will create a model that predicts the topics conveyed by each group 

def topic_modeler(tokenized_texts, no_topics, no_words):
    topics = []

    words = corpora.Dictionary(tokenized_texts)
    corpus = [words.doc2bow(doc) for doc in tokenized_texts]

    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                               id2word=words,
                                                random_state = 3,
                                               num_topics= no_topics)
    
    # Compute Coherence Score
    coherence_model_lda = CoherenceModel(model=lda_model, texts=tokenized_texts, dictionary=words, coherence='c_v')
    coherence_lda = coherence_model_lda.get_coherence()

    return lda_model

# %%
files = glob.glob("scraped_data\*.csv")
dfs = [pd.read_csv(f) for f in files]
df = pd.concat(dfs,ignore_index=True)
df['date'] = [parser.parse(date).strftime('%Y-%m-%d') for date in df['date']]
df = df[(df['text'].str.contains('coronavirus'))]
#df = df[df['category'] == 'Philippines']
df = df.drop_duplicates()
df = df.reset_index(drop = True)


location = pd.read_csv('ph_locations.csv')
location = location.applymap(str.lower)

# %%
# LDA Topics 

words = df['text'].str.lower()
listWords = []
for item in words:
    listWords.append([nlp(item)])

topics = []
for x in listWords:
    res = topic_modeler(x, 1, 30)
    res = res.show_topic(0, topn = 30)
    topics.append([word[0] for word in res])
    
df['LDA_Topics'] = topics

# %%
# Extracting all the counting phrases in the articles

df['count_docs'] =  df['text'].apply(lambda x: re.findall("\d+(?:,\d+)?\s+[a-zA-Z]+", x))

checker = ['confirmed','suspected','quarantine','case','infected','monitoring','chinese','monitored']

count_docs = []
for index, row in df.iterrows():
    passed = []
    for item in row['count_docs']:
        if any(ext in item.lower() for ext in checker):
            passed.append(item)
            break
    
    count_docs.append(passed)

df['count_docs'] = count_docs

# %%
# Extracting all the PH Locations using geotext on the articles

df['PH_Loc'] = [list(set(GeoText(content, 'PH').cities)) for content in df['text']]
df['PH_Loc'] = [[x.lower() for x in w] for w in df['PH_Loc']]
df['PH_Loc'] =[[x.replace('city', '') for x in w] for w in df['PH_Loc']]

# %%
# Identifying which articles are about suspicious or confirmed cases of the virus
status = []
for index, row in df.iterrows():
    if (('confirmed' in row['LDA_Topics']) | ('confirms' in row['LDA_Topics'])| ('confirm' in row['LDA_Topics'])) & ('confirm' in row['title'])  & (row['date'] >= '2020-01-30'):
        status.append('confirmed')
    elif (('confirmed' in row['LDA_Topics']) | ('confirms' in row['LDA_Topics'])| ('confirm' in row['LDA_Topics']))& (row['date'] >= '2020-01-30'):
        status.append('confirmed')
    elif ('confirm' in row['title']) & ('coronavirus' in row['title']) & (row['date'] >= '2020-01-30'):
        status.append('confirmed')
    elif (any(words in row['LDA_Topics']  for words in ['suspected','quarantine','case','infected','monitoring']))& ('FACT CHECK' not in row['title']) & ('FALSE' not in row['title']):
        status.append('suspected')
    else:
        status.append('')
df['status'] = status

# %%
# Selecting Provinces in the identified locations

df['PH_Loc'] = [list(set(loc) & set(location['Pro_Name'].unique())) for loc in df['PH_Loc']]

# %%
# For locations not identified through the text, it will check with the LDA topics if a location is identified and use it instead

for index, row in df.iterrows():
    if len(row['PH_Loc']) == 0:
        try:
            df.loc[index, 'PH_Loc'] = [list(set(row['LDA_Topics']) & set(location['Pro_Name'].unique()))]
        except ValueError:
            continue

# %%
# Cleaning the document counts to just numbers

counts = []
case = []
for count in df['count_docs']:
    try:
        counts.append(count[0].split(' ')[0])
    except IndexError:
        counts.append(0)
        
    try:
        case.append(count[0].split(' ')[1])
    except IndexError:
        case.append('')

df['counts'] = counts
df['counts'] = [str(count).replace(',', '') for count in df['counts']]
df['counts'] = [str(count).replace('.', '') for count in df['counts']]
df['case'] = case

# %%
# Finalizing Locations

ph_loc = []
for loc in df['PH_Loc']:
    try:
        ph_loc.append(loc[0])
    except IndexError:
        ph_loc.append('')
df['Loc'] = ph_loc

# %%
# Fixing confirmed counts

count_fixer = []
for index, row in df.iterrows():
    if (row['status'] == 'confirmed') & (row['case'] != 'confirmed'):
        count_fixer.append(1)
    else:
        count_fixer.append(row['counts'])

df['counts'] = count_fixer

# %%
df.to_csv('test.csv', index = False)

# %% [markdown]
# # Processing for CSV

# %%
df = df.reset_index(drop = True)
df.to_csv('abscbn_parsed.csv', index = False)

# %%
df = pd.read_csv('abscbn_parsed.csv')

# %%
df['source_id'] = 0

# %%
df = df.append(pd.read_csv('rappler_parsed.csv'))

# %%
df = df[df['counts'] != '1300\n\nConfirmed']
df = df[df['Loc'] != ''] #df[df['Loc'].isin(['cebu', 'aklan', 'tarlac','camiguin'])]

# %%
df['counts'] = df.counts.astype(int)

# %%
df = df.sort_values('date')

# %%
def parse(df):
    #print(df.info())
    
    # Get min/max/mean values
    dfa = pd.pivot_table(df, values = 'counts', index=['date', 'Loc'], columns='status', aggfunc=[min, max, np.mean, stats.mode])
    
    # Remove multi-index
    dfa.columns = ["_".join(pair) for pair in dfa.columns]
    dfa = dfa.reset_index()
    
    # Replace 0 with np.nan to forward fill null values
    dfa = dfa.replace(0, np.nan)
    
    # Forward filling needs to be by area
    places = list(df['Loc'].unique())
    
    global dfb
    dfb = pd.DataFrame()
    for place in places:
        df_temp = dfa[dfa['Loc'] == place].fillna(method='ffill')
        dfb = dfb.append(df_temp)
    return dfb

# %%
res = parse(df)

# %%
res
# Out:
#           date       Loc    min_  min_confirmed  min_suspected    max_  \
# 0   2020-01-21  batangas     NaN            NaN            NaN     NaN
# 2   2020-01-23      cebu     NaN            NaN            NaN     NaN
# 1   2020-01-23     aklan     NaN            NaN            3.0     NaN
# 3   2020-01-24      cebu     NaN            NaN           14.0     NaN
# 5   2020-01-25      cebu     NaN            NaN           14.0     NaN
# 4   2020-01-25     aklan     NaN            NaN           80.0     NaN
# 7   2020-01-27      cebu     4.0            NaN           14.0    11.0
# 6   2020-01-27  camiguin     NaN            NaN          106.0     NaN
# 9   2020-01-28      cebu     4.0            NaN           14.0    24.0
# 8   2020-01-28     aklan     NaN            NaN           11.0     NaN
# 11  2020-01-30      cebu     4.0            1.0           14.0    24.0
# 10  2020-01-30     aklan     NaN            1.0           11.0     NaN
# 16  2020-01-31    laguna     NaN            1.0            NaN     NaN
# 12  2020-01-31     aklan     NaN            1.0           11.0     NaN
# 14  2020-01-31     bohol  9700.0            NaN            NaN  9700.0
# 13  2020-01-31   benguet     NaN            NaN            NaN     NaN
# 15  2020-01-31      cebu     4.0            1.0          100.0    24.0
# 17  2020-02-01     aklan    11.0            1.0           11.0    11.0
# 18  2020-02-01      cebu     4.0            1.0          100.0    24.0
# 19  2020-02-02      cebu     4.0            1.0          100.0    24.0
# 21  2020-02-04    iloilo     NaN            NaN            NaN     NaN
# 20  2020-02-04      cebu     4.0            1.0          100.0    24.0
# 22  2020-02-05      cebu     4.0            1.0            3.0    24.0
# 23  2020-02-05    iloilo     NaN            NaN            NaN     NaN
#
#     max_confirmed  max_suspected        mean_  mean_confirmed  mean_suspected  \
# 0             NaN            NaN          NaN             NaN             NaN
# 2             NaN          555.0          NaN             NaN           185.0
# 1             NaN            3.0          NaN             NaN             3.0
# 3             NaN          881.0          NaN             NaN           447.5
# 5             NaN          881.0          NaN             NaN           447.5
# 4             NaN           80.0          NaN             NaN            80.0
# 7             NaN          881.0     8.666667             NaN           447.5
# 6             NaN          106.0          NaN             NaN           106.0
# 9             NaN          881.0     8.000000             NaN           447.5
# 8             NaN           11.0          NaN             NaN            11.0
# 11            1.0          881.0     8.000000             1.0           447.5
# 10            1.0           11.0          NaN             1.0            11.0
# 16            1.0            NaN          NaN             1.0             NaN
# 12            1.0           11.0          NaN             1.0            11.0
# 14            NaN            NaN  9700.000000             NaN             NaN
# 13            NaN            NaN          NaN             NaN             NaN
# 15            1.0          100.0     8.000000             1.0           100.0
# 17            1.0           11.0    11.000000             1.0            11.0
# 18            1.0          100.0     8.000000             1.0           100.0
# 19            1.0          100.0     8.000000             1.0           100.0
# 21            NaN            NaN          NaN             NaN             NaN
# 20            1.0          100.0     8.000000             1.0           100.0
# 22            1.0            3.0     8.000000             1.0             3.0
# 23            NaN            NaN          NaN             NaN             NaN
#
#             mode_ mode_confirmed mode_suspected
# 0             NaN            NaN     ([0], [1])
# 2             NaN            NaN     ([0], [2])
# 1             NaN            NaN     ([3], [1])
# 3             NaN            NaN    ([14], [1])
# 5      ([0], [1])            NaN    ([14], [1])
# 4             NaN            NaN    ([80], [1])
# 7     ([11], [2])            NaN    ([14], [1])
# 6             NaN            NaN   ([106], [1])
# 9      ([0], [2])            NaN    ([14], [1])
# 8             NaN            NaN    ([11], [1])
# 11     ([0], [2])     ([1], [1])     ([0], [2])
# 10            NaN     ([1], [1])    ([11], [1])
# 16            NaN     ([1], [1])            NaN
# 12            NaN     ([1], [1])     ([0], [1])
# 14  ([9700], [1])            NaN            NaN
# 13     ([0], [1])            NaN            NaN
# 15     ([0], [3])     ([1], [4])   ([100], [1])
# 17    ([11], [1])     ([1], [1])     ([0], [1])
# 18     ([0], [4])     ([1], [4])     ([0], [1])
# 19     ([0], [4])     ([1], [2])     ([0], [1])
# 21     ([0], [1])            NaN            NaN
# 20     ([0], [1])     ([1], [1])     ([0], [1])
# 22     ([0], [1])     ([1], [2])     ([3], [1])
# 23     ([0], [1])            NaN            NaN

# %%
res = res[['date','Loc', 'min_suspected','min_confirmed']]

# %%
res = res.fillna(0)

# %%
res = res.sort_values('date')
res
# Out:
#           date       Loc  min_suspected  min_confirmed
# 0   2020-01-21  batangas            0.0            0.0
# 2   2020-01-23      cebu            0.0            0.0
# 1   2020-01-23     aklan            3.0            0.0
# 3   2020-01-24      cebu           14.0            0.0
# 5   2020-01-25      cebu           14.0            0.0
# 4   2020-01-25     aklan           80.0            0.0
# 7   2020-01-27      cebu           14.0            0.0
# 6   2020-01-27  camiguin          106.0            0.0
# 9   2020-01-28      cebu           14.0            0.0
# 8   2020-01-28     aklan           11.0            0.0
# 11  2020-01-30      cebu           14.0            1.0
# 10  2020-01-30     aklan           11.0            1.0
# 16  2020-01-31    laguna            0.0            1.0
# 12  2020-01-31     aklan           11.0            1.0
# 14  2020-01-31     bohol            0.0            0.0
# 13  2020-01-31   benguet            0.0            0.0
# 15  2020-01-31      cebu          100.0            1.0
# 17  2020-02-01     aklan           11.0            1.0
# 18  2020-02-01      cebu          100.0            1.0
# 19  2020-02-02      cebu          100.0            1.0
# 21  2020-02-04    iloilo            0.0            0.0
# 20  2020-02-04      cebu          100.0            1.0
# 22  2020-02-05      cebu            3.0            1.0
# 23  2020-02-05    iloilo            0.0            0.0

# %%
def add_row(df, row):
    df.loc[-1] = row
    df.index = df.index + 1  
    return df.sort_index()

for Loc in res['Loc']:
    sus_holder = 0
    con_holder = 0
    for date in res['date']:
        if sum(res[res['date'] == date]['Loc'].str.contains(Loc)) > 0:
            
            sus_holder = res[(res['date'] == date) & (res['Loc'] == Loc)]['min_suspected'].iloc[0]
            con_holder = res[(res['date'] == date) & (res['Loc'] == Loc)]['min_confirmed'].iloc[0]
        else:
            add_row(res, [date, Loc, sus_holder, con_holder])

# %%
res = res.sort_values('date')

# %%
res
# Out:
#           date       Loc  min_suspected  min_confirmed
# 72  2020-01-21  batangas            0.0            0.0
# 53  2020-01-21  camiguin            0.0            0.0
# 31  2020-01-21     bohol            0.0            0.0
# 59  2020-01-21     aklan            0.0            0.0
# 60  2020-01-21      cebu            0.0            0.0
# 20  2020-01-21   benguet            0.0            0.0
# 9   2020-01-21    iloilo            0.0            0.0
# 42  2020-01-21    laguna            0.0            0.0
# 71  2020-01-23  batangas            0.0            0.0
# 30  2020-01-23     bohol            0.0            0.0
# 52  2020-01-23  camiguin            0.0            0.0
# 41  2020-01-23    laguna            0.0            0.0
# 73  2020-01-23     aklan            3.0            0.0
# 19  2020-01-23   benguet            0.0            0.0
# 8   2020-01-23    iloilo            0.0            0.0
# 74  2020-01-23      cebu            0.0            0.0
# 51  2020-01-24  camiguin            0.0            0.0
# 58  2020-01-24     aklan            3.0            0.0
# 75  2020-01-24      cebu           14.0            0.0
# 40  2020-01-24    laguna            0.0            0.0
# 29  2020-01-24     bohol            0.0            0.0
# 7   2020-01-24    iloilo            0.0            0.0
# 70  2020-01-24  batangas            0.0            0.0
# 18  2020-01-24   benguet            0.0            0.0
# 76  2020-01-25     aklan           80.0            0.0
# 50  2020-01-25  camiguin            0.0            0.0
# 69  2020-01-25  batangas            0.0            0.0
# 77  2020-01-25      cebu           14.0            0.0
# 39  2020-01-25    laguna            0.0            0.0
# 6   2020-01-25    iloilo            0.0            0.0
# ..         ...       ...            ...            ...
# 24  2020-02-01     bohol            0.0            0.0
# 64  2020-02-01  batangas            0.0            0.0
# 90  2020-02-01      cebu          100.0            1.0
# 35  2020-02-01    laguna            0.0            1.0
# 1   2020-02-01    iloilo            0.0            0.0
# 46  2020-02-01  camiguin          106.0            0.0
# 91  2020-02-02      cebu          100.0            1.0
# 56  2020-02-02     aklan           11.0            1.0
# 34  2020-02-02    laguna            0.0            1.0
# 23  2020-02-02     bohol            0.0            0.0
# 12  2020-02-02   benguet            0.0            0.0
# 45  2020-02-02  camiguin          106.0            0.0
# 63  2020-02-02  batangas            0.0            0.0
# 0   2020-02-02    iloilo            0.0            0.0
# 11  2020-02-04   benguet            0.0            0.0
# 44  2020-02-04  camiguin          106.0            0.0
# 92  2020-02-04      cebu          100.0            1.0
# 22  2020-02-04     bohol            0.0            0.0
# 62  2020-02-04  batangas            0.0            0.0
# 33  2020-02-04    laguna            0.0            1.0
# 55  2020-02-04     aklan           11.0            1.0
# 93  2020-02-04    iloilo            0.0            0.0
# 94  2020-02-05      cebu            3.0            1.0
# 95  2020-02-05    iloilo            0.0            0.0
# 10  2020-02-05   benguet            0.0            0.0
# 43  2020-02-05  camiguin          106.0            0.0
# 61  2020-02-05  batangas            0.0            0.0
# 32  2020-02-05    laguna            0.0            1.0
# 54  2020-02-05     aklan           11.0            1.0
# 21  2020-02-05     bohol            0.0            0.0
#
# [96 rows x 4 columns]

# %%
prov = gpd.read_file('prov_shp/prov_geo.shp')

# %%
df = pd.merge(res, prov, left_on = 'Loc', right_on = 'Pro_Name')

# %%
df.head()
# Out:
#          date       Loc  min_suspected  min_confirmed  Pro_Name  \
# 0  2020-01-21  batangas            0.0            0.0  batangas
# 1  2020-01-23  batangas            0.0            0.0  batangas
# 2  2020-01-24  batangas            0.0            0.0  batangas
# 3  2020-01-25  batangas            0.0            0.0  batangas
# 4  2020-01-27  batangas            0.0            0.0  batangas
#
#                                 centroid  \
# 0  13.891920116590907,121.03136855463036
# 1  13.891920116590907,121.03136855463036
# 2  13.891920116590907,121.03136855463036
# 3  13.891920116590907,121.03136855463036
# 4  13.891920116590907,121.03136855463036
#
#                                             geometry
# 0  MULTIPOLYGON (((121.07411 13.53047, 121.07413 ...
# 1  MULTIPOLYGON (((121.07411 13.53047, 121.07413 ...
# 2  MULTIPOLYGON (((121.07411 13.53047, 121.07413 ...
# 3  MULTIPOLYGON (((121.07411 13.53047, 121.07413 ...
# 4  MULTIPOLYGON (((121.07411 13.53047, 121.07413 ...

# %%
df['lat'] = [cor.split(',')[0] for cor in df['centroid']]
df['long'] = [cor.split(',')[1] for cor in df['centroid']]

# %%
df = df[['date','Loc','min_suspected','min_confirmed','long','lat']]
df.columns = (['Date','Location','Suspected','Confirmed','Longitude','Latitude'])

# %%
df['Date'] = [datetime.datetime.strptime(str(date), '%Y-%m-%d').strftime('%Y-%m-%dT%H:%M:%S.%f') for date in df['Date']]

# %%
df = df.sort_values('Date')

# %%
df.to_csv('ncov_parsed.csv', index = False)

# %%
df[df['counts'] == 881]
# Out:
#      source_id source_name        date    category  \
# 132   250107.0     rappler  2020-01-24  Rappler IQ
#
#                                                  title         author  \
# 132  What we learned from SARS, according to ex-DOH...  Janella Paris
#
#                                                   text  \
# 132  Rappler speaks to former health secretary Manu...
#
#                                             LDA_Topics   count_docs  \
# 132  [dayrit, said, health, sars, virus, doh, china...  [881 cases]
#
#              PH_Loc     status  counts   case   Loc
# 132  [cebu, iloilo]  suspected     881  cases  cebu

# %%
df = pd.read_csv('scraped_data/rappler_scraped.csv')

# %%
df = df[df['text'].str.contains('coronavirus')]

# %%
df.to_csv('scraped_data/rappler_scraped.csv', index = False)

# %%
import glob

# %%
files = glob.glob("scraped_data/*.csv")
dfs = [pd.read_csv(f) for f in files]

# %%
df = pd.concat(dfs,ignore_index=True)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                                                 author        category  \
# 0    Shaun Tandon and Arthur MacMillan, Agence Fran...            nCov
# 1                                 Agence France-Presse            nCov
# 2                                              Reuters            nCov
# 3                                         ABS-CBN News            nCov
# 4                                              Reuters            nCov
# 5                                 Lidia Kelly, Reuters            nCov
# 6                     Claire Lee, Agence France-Presse            nCov
# 7                                         ABS-CBN News            nCov
# 8                                 Rocky Swift, Reuters            nCov
# 9                                              Reuters            nCov
# 10                                        ABS-CBN News            nCov
# 11                                        ABS-CBN News            nCov
# 12                                        ABS-CBN News            nCov
# 13                 Stella Qiu and Jamie Freed, Reuters            nCov
# 14           Stephanie Nebehay and Josh Smith, Reuters            nCov
# 15                                Agence France-Presse            nCov
# 16                        Neil Jerome Morales, Reuters            nCov
# 17                      Kristine Sabillo, ABS-CBN News            nCov
# 18                                             Reuters            nCov
# 19   Helen Roxburgh and Danni Zhu, Agence France-Pr...            nCov
# 20                             Jan Yumul, ABS-CBN News            nCov
# 21                                        ABS-CBN News            nCov
# 22                                          Kyodo News            nCov
# 23                              Naomi Tajitsu, Reuters            nCov
# 24       Kiyoshi Takenaka and William Mallard, Reuters            nCov
# 25                                             Reuters            nCov
# 26                                Agence France-Presse            nCov
# 27                                        ABS-CBN News            nCov
# 28                                             Reuters            nCov
# 29                                Agence France-Presse            nCov
# ..                                                 ...             ...
# 364                                         JC Gotinga     Philippines
# 365                               Agence France-Presse     US & Canada
# 366                                        Rappler.com         Move.PH
# 367                                  Boy Ryan B. Zabal     Philippines
# 368                               Agence France Presse    Asia Pacific
# 369                               Agence France Presse    Asia Pacific
# 370                               Agence France Presse    Asia Pacific
# 371                               Agence France Presse       Tech News
# 372                                        Rappler.com     Philippines
# 373                                       Tommy Walker    Asia Pacific
# 374                                         Ralf Rivas     Philippines
# 375                                   John Tan Sitchon     Philippines
# 376                               Agence France-Presse    Asia Pacific
# 377                                          Jojo Dass     Middle East
# 378                                      Janella Paris     Philippines
# 379                                     Sofia Tomacruz     Philippines
# 380                               Agence France-Presse  Global Affairs
# 381                                     Sofia Tomacruz     Philippines
# 382                                        Rappler.com        Business
# 383                               Agence France-Presse     US & Canada
# 384                                        Rappler.com    Asia Pacific
# 385                               Agence France-Presse        Business
# 386                                     Jodesz Gavilan      Rappler IQ
# 387                               Agence France-Presse    Other Sports
# 388                                        Rappler.com     Philippines
# 389                               Agence France-Presse    Asia Pacific
# 390                               Agence France-Presse    Asia Pacific
# 391                                      Janelle Paris     Philippines
# 392                                      Janella Paris     Philippines
# 393                                      Janella Paris     Philippines
#
#                   date  source_id source_name  \
# 0          Feb 22 2020        NaN         NaN
# 1          Feb 22 2020        NaN         NaN
# 2          Feb 22 2020        NaN         NaN
# 3          Feb 22 2020        NaN         NaN
# 4          Feb 22 2020        NaN         NaN
# 5          Feb 22 2020        NaN         NaN
# 6          Feb 22 2020        NaN         NaN
# 7          Feb 22 2020        NaN         NaN
# 8          Feb 20 2020        NaN         NaN
# 9          Feb 20 2020        NaN         NaN
# 10         Feb 19 2020        NaN         NaN
# 11         Feb 19 2020        NaN         NaN
# 12         Feb 19 2020        NaN         NaN
# 13         Feb 19 2020        NaN         NaN
# 14         Feb 19 2020        NaN         NaN
# 15         Feb 18 2020        NaN         NaN
# 16         Feb 18 2020        NaN         NaN
# 17         Feb 18 2020        NaN         NaN
# 18         Feb 18 2020        NaN         NaN
# 19         Feb 18 2020        NaN         NaN
# 20         Feb 17 2020        NaN         NaN
# 21         Feb 17 2020        NaN         NaN
# 22         Feb 17 2020        NaN         NaN
# 23         Feb 17 2020        NaN         NaN
# 24         Feb 15 2020        NaN         NaN
# 25         Feb 15 2020        NaN         NaN
# 26         Feb 15 2020        NaN         NaN
# 27         Feb 15 2020        NaN         NaN
# 28         Feb 15 2020        NaN         NaN
# 29         Feb 15 2020        NaN         NaN
# ..                 ...        ...         ...
# 364  February 01, 2020   250733.0     rappler
# 365  February 01, 2020   250738.0     rappler
# 366  February 01, 2020   250741.0     rappler
# 367  February 01, 2020   250744.0     rappler
# 368  February 01, 2020   250749.0     rappler
# 369  February 01, 2020   250752.0     rappler
# 370  February 01, 2020   250758.0     rappler
# 371  February 01, 2020   250759.0     rappler
# 372  February 01, 2020   250763.0     rappler
# 373  February 01, 2020   250764.0     rappler
# 374  February 01, 2020   250767.0     rappler
# 375  February 01, 2020   250769.0     rappler
# 376  February 02, 2020   250774.0     rappler
# 377  February 02, 2020   250777.0     rappler
# 378  February 02, 2020   250781.0     rappler
# 379  February 02, 2020   250783.0     rappler
# 380  February 02, 2020   250788.0     rappler
# 381  February 02, 2020   250795.0     rappler
# 382  February 02, 2020   250802.0     rappler
# 383  February 02, 2020   250803.0     rappler
# 384  February 02, 2020   250804.0     rappler
# 385  February 02, 2020   250810.0     rappler
# 386  February 02, 2020   250813.0     rappler
# 387  February 02, 2020   250816.0     rappler
# 388  February 02, 2020   250817.0     rappler
# 389  February 02, 2020   250819.0     rappler
# 390  February 02, 2020   250820.0     rappler
# 391   January 30, 2020   186633.0     rappler
# 392  February 02, 2020   250781.0     rappler
# 393  February 05, 2020   251003.0     rappler
#
#                                                   text  \
# 0    \n\n\nMedical staff members preparing equipmen...
# 1    \n\n\nIranian women wearing protective masks t...
# 2    \n\n\nPeople wear masks at a main shopping are...
# 3    \nMANILA (2nd UPDATE)—Filipino repatriates fro...
# 4    \n\n\nMedical workers in protective suits insp...
# 5    \n\n\nPeople wearing face masks walk on Bourke...
# 6    \n\n\nWorkers from a disinfection service comp...
# 7    \n\n\nA resident wears a makeshift protective ...
# 8    \n\n\nA man in a protective clothing is seen o...
# 9    \n\n\nCustomers wearing face masks shop at the...
# 10   \nMANILA, Philippines—The NCAA intends to resu...
# 11   \n\n\nThe cruise ship Diamond Princess, where ...
# 12   \n\n\nPassengers walk out from the cruise ship...
# 13   \n\n\nA China Southern Airlines Airbus commerc...
# 14   \n\n\nNorth Korean leader Kim Jong Un rides a ...
# 15   \n\n\nThe Monaco Formula 1 Grand Prix at the M...
# 16   \n\n\n\nMANILA - Southeast Asia's holiday hot ...
# 17   \n\n\nCommuters mostly wearing face masks cros...
# 18   \n\n\nThe nurses' uniforms hang on the wall of...
# 19   \n\n\nA man wears a protective mask as he watc...
# 20   \n\n\nPhoto courtesy of Jenny Sespene and Kaye...
# 21   \n\n\nStudents, mostly wearing facemasks walk ...
# 22   \nAnother 99 on cruise ship in Yokohama test p...
# 23   \n\n\nPassengers of the cruise ship Diamond Pr...
# 24   \n\n\nPassengers and children stand on the des...
# 25   \n\n\nChinese President Xi Jinping inspects th...
# 26   \n\n\nA woman wears a protective mask in light...
# 27   \n\n\nTourists wear protective face masks at t...
# 28   \n\n\nPeople ride in the skytrain BTS wearing ...
# 29   \n\n\nA staff member wearing a face mask arran...
# ..                                                 ...
# 364  Some 300 Filipinos in Wuhan and other parts of...
# 365  Restrictions will be imposed on American citiz...
# 366  Soon after the memorandum drew flak online, Ad...
# 367  (UPDATED) Both patients are under observation ...
# 368  (UPDATED) Prime Minister Scott Morrison says o...
# 369  The move comes after more than 30 airlines wor...
# 370  The number of visitors to the world's largest ...
# 371  Apple's online store remains open, and the com...
# 372  The airline says all affected guests will be p...
# 373  So far, Hong Kong still lags behind China, Sin...
# 374  'Spreading fake news and racist, xenophobic me...
# 375  The Department of Trade and Industry, however,...
# 376  With public anger mounting in China, Wuhan's t...
# 377  In a media advisory, the Emirates News Agency ...
# 378  (3rd UPDATE) The first confirmed death in the ...
# 379  (UPDATED) Only Filipino citizens and permanent...
# 380  From border closures to flight bans, here are ...
# 381  'Walang iisang may kasalanan tayo, kaya tayo, ...
# 382  The woman and man found to have the novel coro...
# 383  US Secretary of State Mike Pompeo meets top of...
# 384  A 'highly pathogenic strain' of the virus has ...
# 385  The People's Bank of China says it will mainta...
# 386  Wuhan City, the biggest in Hubei province, is ...
# 387  Japan has warned citizens against non-essentia...
# 388  The Philippines temporarily stops issuing visa...
# 389  Chinese state media says some 1,400 military m...
# 390  Many foreign students and workers see no reaso...
# 391  (3rd UPDATE) The Philippines' first 2019-nCoV ...
# 392  (3rd UPDATE) The first confirmed death in the ...
# 393  (6th UPDATE) The Department of Health is probi...
#
#                                                  title
# 0    Russia-linked disinformation campaign fueling ...
# 1     Iran reports 1 death among 10 new COVID-19 cases
# 2    Chinese provincial gov’t: COVID-19 incubation ...
# 3    Pinoy repatriates quarantined at New Clark Cit...
# 4    China brings in 7 cruise ships to house Wuhan ...
# 5    Australia reopens doors to some Chinese studen...
# 6    South Korea reports surge in virus cases linke...
# 7    Drop in new China virus cases as toll reaches ...
# 8    Japanese data on cruise ship coronavirus infec...
# 9    Taiwan bans Italian pig imports in quarrel ove...
# 10   NCAA plans March 16 return after postponing ga...
# 11   Filipino sailor in Japan cruise ship cleared o...
# 12   DFA orders repatriation of Filipinos aboard vi...
# 13   Foreign pilots at Chinese airlines return home...
# 14   WHO says 'no indications' of coronavirus cases...
# 15   Formula 1: Vietnam Grand Prix gets go-ahead de...
# 16   Southeast Asia's tourist hubs court local mark...
# 17   PH says it’s safe to attend public gatherings ...
# 18   Hospital director dies in China's Wuhan, epice...
# 19   Coronavirus casts shadow on China's big screen...
# 20   Workers, migrants call on PH gov't to review H...
# 21   Duque says COVID-19 'contact tracing' reaching...
# 22   Japan issues coronavirus medical guidance as i...
# 23   Japan keeps high coronavirus alert as more cit...
# 24   US to evacuate Americans aboard cruise ship qu...
# 25   Xi Jinping: China must keep economic, social o...
# 26   France announces first coronavirus death outsi...
# 27   Public masses in Singapore suspended amid coro...
# 28   Thailand reports 1 new case of coronavirus, br...
# 29   China cleans, locks away banknotes to stop vir...
# ..                                                 ...
# 364  DOH eyes Caballo Island, Fort Magsaysay as qua...
# 365  U.S. declares virus 'emergency,' bans traveler...
# 366  Adamson University under fire for ‘racist’ saf...
# 367  Chinese tourist, flight crew 'isolated' in Akl...
# 368  Australia to refuse entry to non-citizens arri...
# 369       China flies citizens home to virus-hit Wuhan
# 370      China virus silences Macau's bustling casinos
# 371  Apple closes China stores until Feb 9 due to v...
# 372          AirAsia cancels selected PH-China flights
# 373         Hong Kong braces for spread of coronavirus
# 374  Racism more dangerous than novel coronavirus –...
# 375  Amid coronavirus scare, face masks fly off the...
# 376             China virus death toll surges past 300
# 377               UAE announces fifth coronavirus case
# 378  First nCoV-related death outside China as pati...
# 379  Duterte expands ban on travelers from China, H...
# 380  China coronavirus outbreak: How governments ha...
# 381  Robredo urges Filipinos to respect Chinese ami...
# 382  Cebu Pacific alerts fellow passengers of Phili...
# 383  Pompeo condemns China's Xinjiang crackdown dur...
# 384    H5N1 bird flu outbreak reported in Hunan, China
# 385  Chinese central bank to pump $173 billion into...
# 386  Beyond coronavirus: Things to know about China...
# 387  Tokyo to 'strengthen testing' for coronavirus ...
# 388  PH expands visa suspension for travelers from ...
# 389             Chinese army to oversee virus hospital
# 390  More foreigners leaving China as virus fears m...
# 391  Philippines confirms 1st case of novel coronav...
# 392  First nCoV-related death outside China as pati...
# 393  Philippines confirms 3rd case of novel coronav...
#
# [394 rows x 7 columns]
